# %%
import pandas as pd


data =[10,20,30,40]
Series = pd.Series(data)
print(Series)

 #dding custom index to the Series
series_with_index = pd.Series(data, index=['a', 'b', 'c', 'd'])
print(series_with_index)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df = pd.read_csv('/content/India_GDP_1960-2022.csv')

print(df.head())

print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
# Out:
#    Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0           0  2021             3173.40                182160      8.95
# 1           1  2020             2667.69                154640     -6.60
# 2           2  2019             2831.55                165760      3.74
# 3           3  2018             2702.93                159840      6.45
# 4           4  2017             2651.47                158480      6.80
#    Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0           0  2021             3173.40                182160      8.95
# 1           1  2020             2667.69                154640     -6.60
# 2           2  2019             2831.55                165760      3.74
# 3           3  2018             2702.93                159840      6.45
# 4           4  2017             2651.47                158480      6.80
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# ...

# %%
df.head()  # First 5 rows
df.tail(10)  # Last 3 rows
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 52          52  1969               58.45                  8640      6.54
# 53          53  1968               53.09                  8000      3.39
# 54          54  1967               50.13                  7680      7.83
# 55          55  1966               45.87                  7200     -0.06
# 56          56  1965               59.55                  9520     -2.64
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            62 non-null     int64
#  1   year                  62 non-null     int64
#  2   GDP in (Billion) $    62 non-null     float64
#  3   Per Capita in rupees  62 non-null     int64
#  4   Growth %              62 non-null     float64
# dtypes: float64(2), int64(3)
# memory usage: 2.5 KB

# %%
df.describe
df.shape
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'GDP in (Billion) $', 'Per Capita in rupees',
#        'Growth %'],
#       dtype='object')

# %%
df['GDP in (Billion) $']  # Single column
df[['GDP in (Billion) $', 'Growth %']]  # Multiple columns
# Out:
#     GDP in (Billion) $  Growth %
# 0              3173.40      8.95
# 1              2667.69     -6.60
# 2              2831.55      3.74
# 3              2702.93      6.45
# 4              2651.47      6.80
# ..                 ...       ...
# 57               56.48      7.45
# 58               48.42      5.99
# 59               42.16      2.93
# 60               39.23      3.72
# 61               37.03      0.00
#
# [62 rows x 2 columns]

# %%
df.iloc[0]  # First row
df.loc[0]  # Row with index label 0
# Out:
# Unnamed: 0                   0.00
# year                      2021.00
# GDP in (Billion) $        3173.40
# Per Capita in rupees    182160.00
# Growth %                     8.95
# Name: 0, dtype: float64

# %%
df[df['Growth %'] > 8]
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0            0  2021             3173.40                182160      8.95
# 5            5  2016             2294.80                138640      8.26
# 11          11  2010             1675.62                108640      8.50
# 15          15  2006              940.26                 64560      8.06
# 22          22  1999              458.82                 35360      8.85
# 33          33  1988              296.59                 28320      9.63
# 46          46  1975               98.47                 12640      9.15

# %% [markdown]
# Day 4: Data Cleaning and Transformation
# **bold text**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# year                    0
# GDP in (Billion) $      0
# Per Capita in rupees    0
# Growth %                0
# dtype: int64

# %%
df.fillna(0)
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0            0  2021             3173.40                182160      8.95
# 1            1  2020             2667.69                154640     -6.60
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
# [62 rows x 5 columns]

# %%
df.dropna()
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0            0  2021             3173.40                182160      8.95
# 1            1  2020             2667.69                154640     -6.60
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
# [62 rows x 5 columns]

# %%
df.rename(columns={'GDP in (Billion) $': 'GDP'})
# Out:
#     Unnamed: 0  year      GDP  Per Capita in rupees  Growth %
# 0            0  2021  3173.40                182160      8.95
# 1            1  2020  2667.69                154640     -6.60
# 2            2  2019  2831.55                165760      3.74
# 3            3  2018  2702.93                159840      6.45
# 4            4  2017  2651.47                158480      6.80
# ..         ...   ...      ...                   ...       ...
# 57          57  1964    56.48                  9280      7.45
# 58          58  1963    48.42                  8080      5.99
# 59          59  1962    42.16                  7200      2.93
# 60          60  1961    39.23                  6800      3.72
# 61          61  1960    37.03                  6560      0.00
#
# [62 rows x 5 columns]

# %%
df.groupby('Growth %').sum()
# Out:
#           Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees
# Growth %
# -6.60              1  2020             2667.69                154640
# -5.24             42  1979              152.99                 17920
# -2.64             56  1965               59.55                  9520
# -0.55             49  1972               71.46                  9840
# -0.06             55  1966               45.87                  7200
#  0.00             61  1960               37.03                  6560
#  1.06             30  1991              270.11                 24240
#  1.19             47  1974               99.53                 13040
#  1.64             50  1971               67.35                  9520
#  1.66             45  1976              102.72                 12880
#  2.93             59  1962               42.16                  7200
#  3.09             13  2008             1198.90                 79920
# ...

# %%
df.pivot_table(index='Growth %', values='GDP in (Billion) $', aggfunc='sum')
# Out:
#           GDP in (Billion) $
# Growth %
# -6.60                2667.69
# -5.24                 152.99
# -2.64                  59.55
# -0.55                  71.46
# -0.06                  45.87
#  0.00                  37.03
#  1.06                 270.11
#  1.19                  99.53
#  1.64                  67.35
#  1.66                 102.72
#  2.93                  42.16
#  3.09                1198.90
#  3.30                  85.52
#  3.39                  53.09
#  3.48                 200.72
#  3.72                  39.23
#  3.74                2831.55
#  3.80                 514.94
#  3.82                 212.16
#  3.84                 468.39
#  3.97                 279.03
#  4.05                 415.87
#  4.75                 279.30
#  4.78                 248.99
#  4.82                 485.44
#  5.16                  62.42
#  5.24                1823.05
#  5.25                 232.51
#  5.46                1827.64
#  5.48                 288.21
# ...

# %%
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'City': ['New York', 'Chicago']})
merged_df = pd.merge(df1, df2, on='Name')
pd.concat([df1, df2], axis=1)  # Concatenate along columns

df1.set_index('Name').join(df2.set_index('Name'))
# Out:
#        Age      City
# Name
# Alice   25  New York
# Bob     30   Chicago

# %%
df["gdp"]= df["GDP in (Billion) $"].apply(lambda x: x **2)
print(df)
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %  \
# 0            0  2021             3173.40                182160      8.95
# 1            1  2020             2667.69                154640     -6.60
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 57          57  1964               56.48                  9280      7.45
# 58          58  1963               48.42                  8080      5.99
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
#              gdp
# 0   1.007047e+07
# 1   7.116570e+06
# 2   8.017675e+06
# 3   7.305831e+06
# ...

# %%
df.sort_values('GDP in (Billion) $', ascending=False)
# Out:
#     Unnamed: 0  year  GDP in (Billion) $  Per Capita in rupees  Growth %  \
# 0            0  2021             3173.40                182160      8.95
# 2            2  2019             2831.55                165760      3.74
# 3            3  2018             2702.93                159840      6.45
# 1            1  2020             2667.69                154640     -6.60
# 4            4  2017             2651.47                158480      6.80
# ..         ...   ...                 ...                   ...       ...
# 58          58  1963               48.42                  8080      5.99
# 55          55  1966               45.87                  7200     -0.06
# 59          59  1962               42.16                  7200      2.93
# 60          60  1961               39.23                  6800      3.72
# 61          61  1960               37.03                  6560      0.00
#
#              gdp
# 0   1.007047e+07
# 2   8.017675e+06
# 3   7.305831e+06
# 1   7.116570e+06
# ...
